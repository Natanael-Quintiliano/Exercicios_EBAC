# %% [markdown]
# # Questões  <a name="questoes"></a>
# 1. [Vestibular](#vestibular)
# 2. [Vestibular II](#vestibularII)
# 3. [Vacinações no Acre](#vacinacao)
# 4. [Vacinacao II](#vacinacaoII)

# %%
"""
Importando as bibliotecas
"""
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Vestibular <a name="vestibular"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#questoes)

# %% [markdown]
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# A) (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# B) (operações entre *DataFrames*) Calcule o total de acertos de cada aluno.
# C) Calcule o porcentual geral de cada aluno.
# D) Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
"""
Criação dos Dataframes necessarios
"""
np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
"""
A) (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.  
B) (operações entre *DataFrames) Calcule o total de acertos de cada aluno.  
C) Calcule o porcentual geral de cada aluno.

Criei um Dataframe com o total de acertos e porcentual de acertos por assunto de cada aluno.Em seguida calculei o porcentual
total de acertos baseado na quantidade de acertos totais.
"""

df_primeira_fase = pd.DataFrame({'Qt_acertos_Mat': df_mat['Qt_acertos'],
                                 'Porc_acertos_Mat': (df_mat['Qt_acertos'] / 24) * 100,
                                 'Qt_acertos_Por': df_por['Qt_acertos'],
                                 'Porc_acertos_Por': (df_por['Qt_acertos'] / 18) * 100,
                                 'Qt_acertos_Geo': df_geo['Qt_acertos'],
                                 'Porc_acertos_Geo': (df_geo['Qt_acertos'] / 8) * 100,
                                 'Qt_acertos_Ing': df_ing['Qt_acertos'],
                                 'Porc_acertos_Ing': (df_ing['Qt_acertos'] / 8) * 100,
                                 'Qt_acertos_His': df_his['Qt_acertos'],
                                 'Porc_acertos_His': (df_his['Qt_acertos'] / 8) * 100,
                                 'Qt_acertos_Fis': df_fis['Qt_acertos'],
                                 'Porc_acertos_Fis': (df_fis['Qt_acertos'] / 12) * 100,
                                 'Qt_acertos_Qui': df_qui['Qt_acertos'],
                                 'Porc_acertos_Qui': (df_qui['Qt_acertos'] / 12) * 100,
                                 'Total_acertos': df_mat['Qt_acertos'] + 
                                                  df_por['Qt_acertos'] +
                                                  df_geo['Qt_acertos'] +
                                                  df_ing['Qt_acertos'] +
                                                  df_his['Qt_acertos'] +
                                                  df_fis['Qt_acertos'] +
                                                  df_qui['Qt_acertos']
                               })

df_primeira_fase['Porc_total_acertos'] = (df_primeira_fase['Total_acertos'] / 90) * 100
pd.set_option('display.precision', 2)
df_primeira_fase.head(20)
# Out:
#     Qt_acertos_Mat  Porc_acertos_Mat  Qt_acertos_Por  Porc_acertos_Por  \
# 0                6             25.00               7             38.89
# 1               19             79.17              10             55.56
# 2               14             58.33              16             88.89
# 3               10             41.67               7             38.89
# 4                7             29.17               2             11.11
# 5               20             83.33               2             11.11
# 6                6             25.00               0              0.00
# 7               18             75.00               4             22.22
# 8               22             91.67               9             50.00
# 9               10             41.67               6             33.33
# 10              10             41.67               8             44.44
# 11              23             95.83               6             33.33
# ...

# %%
"""
D) Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?
""" 
len(df_alunos[df_alunos['Total_acertos'] > 45])
# Out:
# 31

# %%
"""
E) Bonus: Criei uma coluna dizendo se foram aprovados ou não para a segunda fase.
"""             
df_primeira_fase['Aprovados'] = ['Sim' if Total_acertos >= 45 else 'Não' for Total_acertos in df_primeira_fase['Total_acertos']]
df_primeira_fase.head(20)
# Out:
#     Qt_acertos_Mat  Porc_acertos_Mat  Qt_acertos_Por  Porc_acertos_Por  \
# 0                6             25.00               7             38.89
# 1               19             79.17              10             55.56
# 2               14             58.33              16             88.89
# 3               10             41.67               7             38.89
# 4                7             29.17               2             11.11
# 5               20             83.33               2             11.11
# 6                6             25.00               0              0.00
# 7               18             75.00               4             22.22
# 8               22             91.67               9             50.00
# 9               10             41.67               6             33.33
# 10              10             41.67               8             44.44
# 11              23             95.83               6             33.33
# ...

# %% [markdown]
# # 2. Vestibular II <a name="vestibularII"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#questoes)

# %% [markdown]
# Ainda sobre o mesmo banco de dados:
#
# A) Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
#
# B) Quantos são esses alunos?
#
# C) Qual a média desses alunos em história e geografia?
#
# D) Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
"""
Primeiro criei um Dataframe novo apenas com quem foi aprovado para segunda fase, isto é acertou mais de 45 questões. Depois 
filtrei apenas acertos e porcentagem de acertos em Mat,Fis e Qui, além do total e porcentgem geral.
"""
df_primeira_fase_filtrado = df_primeira_fase[(df_primeira_fase['Total_acertos'] > 45)]

df_primeira_fase_filtrado['Total_acertos_Mat,Fis,Qui'] = (df_primeira_fase_filtrado['Qt_acertos_Mat'] +
                                                         df_primeira_fase_filtrado['Qt_acertos_Fis'] +
                                                         df_primeira_fase_filtrado['Qt_acertos_Qui'])
        
df_primeira_fase_filtrado['Porc_total_acertos_Mat,Fis,Qui'] = (df_primeira_fase_filtrado['Total_acertos_Mat,Fis,Qui'] / 48) * 100

pd.set_option('display.precision', 2)

df_primeira_fase_filtrado.head(20)
# Out:
# C:\Users\Natanael_Quintiliano\AppData\Local\Temp\ipykernel_8840\78851946.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_primeira_fase_filtrado['Total_acertos_Mat,Fis,Qui'] = (df_primeira_fase_filtrado['Qt_acertos_Mat'] +
# C:\Users\Natanael_Quintiliano\AppData\Local\Temp\ipykernel_8840\78851946.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_primeira_fase_filtrado['Porc_total_acertos_Mat,Fis,Qui'] = (df_primeira_fase_filtrado['Total_acertos_Mat,Fis,Qui'] / 48) * 100
# ...

# %%
""" 
A) Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos
desqualificados por este critério.

B) Quantos são esses alunos?

Aqui uso o Dataframe acima para selecionar os alunos que zeraram em uma das 3 materias e conto eles
"""
df_eliminados = df_primeira_fase_filtrado[(df_primeira_fase_filtrado['Qt_acertos_Mat'] == 0)|
                                          (df_primeira_fase_filtrado['Qt_acertos_Fis'] == 0)|
                                          (df_primeira_fase_filtrado['Qt_acertos_Qui'] == 0)]
len(df_eliminados)
# Out:
# 5

# %%
"""
C) Qual a média desses alunos em história e geografia?
"""
df_eliminados['Media_acertos_His,Geo'] = ((df_primeira_fase_filtrado['Qt_acertos_His'] +
                                          df_primeira_fase_filtrado['Qt_acertos_Geo']) / 2) 

pd.set_option('display.precision', 2)
        
df_eliminados
# Out:
# C:\Users\Natanael_Quintiliano\AppData\Local\Temp\ipykernel_8840\231202519.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eliminados['Media_acertos_His,Geo'] = ((df_primeira_fase_filtrado['Qt_acertos_His'] +
#     Qt_acertos_Mat  Porc_acertos_Mat  Qt_acertos_Por  Porc_acertos_Por  \
# 20              23             95.83              11             61.11
# 27              21             87.50              13             72.22
# 35              11             45.83              14             77.78
# 72              11             45.83              16             88.89
# 89              23             95.83              11             61.11
#
#     Qt_acertos_Geo  Porc_acertos_Geo  Qt_acertos_Ing  Porc_acertos_Ing  \
# ...

# %%
"""
D) Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido 
desqualificados.
"""
df_aprovados = df_primeira_fase_filtrado[(df_primeira_fase_filtrado['Qt_acertos_Mat'] >= 1)|
                                         (df_primeira_fase_filtrado['Qt_acertos_Fis'] >= 1)|
                                         (df_primeira_fase_filtrado['Qt_acertos_Qui'] >= 1)]
df_aprovados
# Out:
#     Qt_acertos_Mat  Porc_acertos_Mat  Qt_acertos_Por  Porc_acertos_Por  \
# 1               19             79.17              10             55.56
# 2               14             58.33              16             88.89
# 5               20             83.33               2             11.11
# 7               18             75.00               4             22.22
# 8               22             91.67               9             50.00
# 17              21             87.50              15             83.33
# 18              20             83.33               4             22.22
# 20              23             95.83              11             61.11
# 24              20             83.33               2             11.11
# 27              21             87.50              13             72.22
# 31              15             62.50              13             72.22
# 35              11             45.83              14             77.78
# ...

# %% [markdown]
# # 3. Vacinações no Acre <a name="vacinacao"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#questoes)

# %% [markdown]
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# A) Quantas vacinas estão registradas nessa base?
# B) Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# C) Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# D) Quantos pacientes com menos de 18 anos foram vacinados?
# E) Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
"""
Primeiro passo é criar o dataframe com os dados da vacinação.
"""
df_vacinacao = pd.read_csv('Dados_AC_Parte_1.csv', sep= ";")
df_vacinacao
# Out:
#                                       document_id  \
# 0       2c2859b1-5fc7-4fa7-8a43-55700cc08c80-i0b0
# 1       f44fa061-8b0e-4e3f-a238-a4814b775d2a-i0b0
# 2       31abd53c-d5a1-431f-b9d3-845e8ca2160f-i0b0
# 3       f481c826-6b38-4008-8959-265d1c2fc82f-i0b0
# 4       50766f6e-1d03-4fdc-8d2e-08cb0ab5a045-i0b0
# ...                                           ...
# 379370  042edb53-bb3f-4111-ac40-67de11988b73-i0b0
# 379371  0454ba9b-d5d4-44de-a205-703aa8afb6a0-i0b0
# 379372  04676d11-aafb-477c-bc90-35ac073e9570-i0b0
# 379373  04998614-b613-4d70-bd14-7dcd1a7ee627-i0b0
# 379374  04b5bc9e-1a72-46e9-af2b-b7aaabd3c3e4-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       3c448ba92490fbf7e5f6e0b1b83606b09c00e59bdf293c...              54
# 1       dd5749be588f67065869ae7cc7c92123d74af747b68b24...              22
# 2       4a04804ff02ee546229c87747d998091ead26fcc1738c7...              33
# ...

# %%
"""
A primeira coisa a ver neste dataframe são os valores 'Nan' para utilizarmos 'nunique' corretamente.
"""
df_vacinacao.isnull().sum()
# Out:
# document_id                                     0
# paciente_id                                     0
# paciente_idade                                  0
# paciente_dataNascimento                         0
# paciente_enumSexoBiologico                      0
# paciente_racaCor_codigo                         0
# paciente_racaCor_valor                          0
# paciente_endereco_coIbgeMunicipio            2354
# paciente_endereco_coPais                     2348
# paciente_endereco_nmMunicipio                2349
# paciente_endereco_nmPais                     2348
# paciente_endereco_uf                         2354
# paciente_endereco_cep                       55455
# paciente_nacionalidade_enumNacionalidade      178
# estabelecimento_valor                           0
# estabelecimento_razaoSocial                     0
# estalecimento_noFantasia                        0
# estabelecimento_municipio_codigo                0
# estabelecimento_municipio_nome                  0
# ...

# %%
"""
A) Quantas vacinas estão registradas nessa base? 

A pergunta achei ambigua então pesquisei os nomes das vacinas. Primeiro verifiquei se havia NaN e depois a quantidade de valores
unicos em 'vacina_nome', o total é de 11 vacinas porque existem valores NaN.
"""
df_vacinacao['vacina_nome'].nunique()
# Out:
# 12

# %%
"""
B) Quantos pacientes foram vacinados? (considere um paciente para cada valor único de 'paciente_id') 

Primeiro verifiquei se havia NaN e depois a quantidade de valores unicos em 'paciente_id',não havia valores NaN.

"""
df_vacinacao['paciente_id'].nunique()
# Out:
# 311372

# %%
"""
C) Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o
método '.unique()'.  

Primeiro seleciono apenas primeira dose no campo 'vacina_descricao_dose' e crio a variavel 'df_primeira_dose' e depois filtro os
'paciente_id' utilizado a variavel.
"""
df_primeira_dose = df_vacinacao[df_vacinacao['vacina_descricao_dose']=='1ª Dose']

df_primeira_dose['paciente_id'].nunique()
# Out:
# 141862

# %%
"""
Solução alternativa

C) Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o
método '.unique()'.  
"""
df_primeira_dose_b = df_vacinacao['vacina_descricao_dose'].unique()[0]   

df_vacinacao['paciente_id'].loc[df_vacinacao['vacina_descricao_dose'] == df_primeira_dose_b].nunique()
# Out:
# 141862

# %%
"""
D) Quantos pacientes com menos de 18 anos foram vacinados?  

Primeiro seleciono apenas primeira dose no campo 'paciente_idade' e crio a variavel 'df_menor' e depois filtro os 'paciente_id'
utilizado a variavel.
"""
df_menor = df_vacinacao[df_vacinacao['paciente_idade']<18]

df_menor['paciente_id'].nunique()
# Out:
# 64883

# %%
"""
E) Quantos estabelecimentos aplicaram vacina no Acre?

Primeiro verifiquei se havia NaN e depois a quantidade de valores unicos em 'estalecimento_noFantasia',não havia valores NaN.
"""
df_vacinacao['estalecimento_noFantasia'].nunique()
# Out:
# 208

# %% [markdown]
# # 4. Vacinação II <a name="vacinacaoII"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#questoes)

# %% [markdown]
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# A) crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
#
# B) crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
#
# C) Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
#
# D) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
#
# E) usando o método *.loc*, selecione somente essas variáveis  .
#
# F) Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
"""
A) Crie uma cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos. 
""" 
df_menor = df[df["paciente_idade"]<18].copy()

# %%
"""
B) Crie uma lista das colunas desse DataFrame com o atributo de DataFrame.columns().
                
Criei uma variavel com uma lista das colunas do dataframe 'df_menor'
"""
colunas = df_menor.columns
colunas

# %%
"""
C) Nesse DataFrame faça uma contagem do campo 'vacina_categoria_nome'.
"""
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      44257
# Povos Indígenas                                    3998
# Outros                                             3697
# Povos e Comunidades Tradicionais                    681
# Trabalhadores de Saúde                              238
# Comorbidades                                         55
# População Privada de Liberdade                       51
# Gestantes                                            36
# Pessoas com Deficiência                              10
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Name: count, dtype: int64

# %%
""" 
D) A partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, 
faça uma lista com esses valores.
"""
lista_var_estabelecimento = ['estabelecimento_valor',
                             'estabelecimento_razaoSocial',
                             'estalecimento_noFantasia',
                             'estabelecimento_municipio_codigo',
                             'estabelecimento_municipio_nome',
                             'estabelecimento_uf']
lista_var_estabelecimento
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
"""
E) Usando o método .loc, selecione somente essas variáveis
"""
df_lista_var_est = df_menor.loc[:,lista_var_estabelecimento]

df_lista_var_est
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 3                     2002922            SECRETARIA MUNICIPAL DE SAUDE
# 5                     6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 8                      924490            PREFEITURA MUNICIPAL DE FEIJO
# 9                     2002922            SECRETARIA MUNICIPAL DE SAUDE
# 11                    2001217           PREFEITURA MUNICIPAL DE XAPURI
# ...                       ...                                      ...
# 379361                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 379362                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 379364                3810771         PREFEITURA MUNICIPAL DE TARAUACA
# 379366                2001314   PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 379370                2000237  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
#
#                                  estalecimento_noFantasia  \
# ...

# %%
"""
F) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento
"""
df_lista_var_est = df_lista_var_est.drop_duplicates()

df_lista_var_est
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 3                     2002922               SECRETARIA MUNICIPAL DE SAUDE
# 5                     6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 8                      924490               PREFEITURA MUNICIPAL DE FEIJO
# 11                    2001217              PREFEITURA MUNICIPAL DE XAPURI
# 12                    2000482          PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                         ...
# 86055                 3015513          PREFEITURA MUNICIPAL DE RIO BRANCO
# 169068                 499919            MUNICIPIO DE SANTA ROSA DO PURUS
# 213508                 755605                          USF BARRO VERMELHO
# 221824                7123043              PREFEITURA MUNICIPAL DE JORDAO
# 255386                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
#
#                                  estalecimento_noFantasia  \
# ...
